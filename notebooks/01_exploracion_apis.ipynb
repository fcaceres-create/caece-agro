# %% [markdown]
# # 01 - Exploración de APIs
#
# Notebook de exploración inicial de las APIs externas (MAGyP, Open-Meteo, SoilGrids).
# Objetivo: entender los endpoints, el formato de las respuestas y validar que se
# puede construir el dataset maestro consultando coordenadas argentinas.
