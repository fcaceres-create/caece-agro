# %% [markdown]
# # 03 - Modelado
#
# Entrenamiento y evaluación del modelo de regresión de rendimiento por cultivo
# (Random Forest). Compara métricas, analiza importancia de variables y persiste
# los modelos para que los consuma el integrador.
